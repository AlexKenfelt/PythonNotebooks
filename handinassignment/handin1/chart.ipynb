# %%
import pandas as pd
# (2.) Pie chart for task 2.
data = pd.read_csv('./Highest Holywood Grossing Movies.csv', skiprows=0)

license = pd.Series(data['License'])   


license_count = license.value_counts() 
license_count.plot(kind='pie', autopct='%1.0f%%')
